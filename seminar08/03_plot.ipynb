# %%
import numpy as np

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot((np.arange(21) - 10)**2)
plt.show()

# %%
plt.plot(np.sin(np.arange(-5, 5, 0.01)))
plt.show()

# %%
x = np.arange(-10, 10, 0.01)

# %%
y = np.sin(x) + np.cos(0.5*x)

# %%
plt.plot(x, y)
plt.show()
